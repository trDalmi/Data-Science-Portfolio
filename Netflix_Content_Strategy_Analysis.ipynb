# %% [markdown]
# <a href="https://colab.research.google.com/github/trDalmi/Data-Science-Portfolio/blob/main/Netflix_Content_Strategy_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/netflix_content_2023.csv')
df.sample(5)
# Out:
#                                                   Title Available Globally?  \
# 7519                              The Letdown: Season 2                 Yes
# 12111  Rayah El Madam: Season 1 // ريح المدام: Season 1                  No
# 2999                                        Point Blank                 Yes
# 21068        The Magic School Bus Rides Again: Season 2                 Yes
# 9386                          Berlin, Berlin: Staffel 1                  No
#
#       Release Date Day of Week Hours Viewed Language Indicator Content Type
# 7519     7/31/2019         Wed    12,00,000            English         Show
# 12111          NaN         Sat     3,00,000        Non-English         Show
# 2999     7/12/2019         Fri    63,00,000            English        Movie
# 21068    4/13/2018         Fri    34,00,000            English         Show
# 9386           NaN         Sat     6,00,000            English        Movie

# %%
# !pip install ydata-profiling
# from ydata_profiling import ProfileReport
# profile = ProfileReport(df, title='Netflix Report')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24812 entries, 0 to 24811
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                24812 non-null  object
#  1   Available Globally?  24812 non-null  object
#  2   Release Date         8166 non-null   object
#  3   Day of Week          24812 non-null  object
#  4   Hours Viewed         24812 non-null  object
#  5   Language Indicator   24812 non-null  object
#  6   Content Type         24812 non-null  object
# dtypes: object(7)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                             Title Available Globally? Release Date  \
# count                       24812               24812         8166
# unique                      19158                   2         1783
# top     The Night Agent: Season 1                  No    3/20/2020
# freq                            2               17162           28
#
#        Day of Week Hours Viewed Language Indicator Content Type
# count        24812        24812              24812        24812
# unique           7          889                  6            2
# top            Sat     1,00,000            English        Movie
# freq         16884         4046              17268        14104

# %%
df.isnull().sum()
# Out:
# Title                      0
# Available Globally?        0
# Release Date           16646
# Day of Week                0
# Hours Viewed               0
# Language Indicator         0
# Content Type               0
# dtype: int64

# %%
df.shape
# Out:
# (24812, 7)

# %%
df.fillna(value = "NaN")
# Out:
#                                               Title Available Globally?  \
# 0                         The Night Agent: Season 1                 Yes
# 1                         Ginny & Georgia: Season 2                 Yes
# 2                The Glory: Season 1 // 더 글로리: 시즌 1                 Yes
# 3                               Wednesday: Season 1                 Yes
# 4               Queen Charlotte: A Bridgerton Story                 Yes
# ...                                             ...                 ...
# 24807            We Are Black and British: Season 1                  No
# 24808             Whitney Cummings: Can I Touch It?                 Yes
# 24809                       Whitney Cummings: Jokes                  No
# 24810  Whose Vote Counts, Explained: Limited Series                 Yes
# 24811   Zach Galifianakis: Live at the Purple Onion                  No
#
#       Release Date Day of Week  Hours Viewed Language Indicator Content Type
# ...

# %%
df = df.dropna()

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                              Title Available Globally?  \
# 0                        The Night Agent: Season 1                 Yes
# 1                        Ginny & Georgia: Season 2                 Yes
# 2               The Glory: Season 1 // 더 글로리: 시즌 1                 Yes
# 3                              Wednesday: Season 1                 Yes
# 4              Queen Charlotte: A Bridgerton Story                 Yes
# ...                                            ...                 ...
# 8161                            Vir Das: Losing It                 Yes
# 8162           W. Kamau Bell: Private School Negro                 Yes
# 8163             Whitney Cummings: Can I Touch It?                 Yes
# 8164                       Whitney Cummings: Jokes                  No
# 8165  Whose Vote Counts, Explained: Limited Series                 Yes
#
#      Release Date Day of Week  Hours Viewed Language Indicator Content Type  \
# ...

# %%
types of content.....
most day on which the content is released
month wise trend.. which month has most release.
                   which type of content gets released on seasonal trend and compare season of differen years.
                   what is the effect of day of release on the views.
                   what is the effect of the season on the views.
which language has the highes views.
which language is what content heavy.
what would be a good time to relase, what kind of content.

# %%
# Calculate the frequency of each day of the week
df['Day of Week'].value_counts()
# Out:
# Day of Week
# Sat    16884
# Fri     3863
# Wed     1310
# Thu     1145
# Tue      995
# Mon      436
# Sun      179
# Name: count, dtype: int64

# %% [markdown]
# For this we can see that most of the content is released on saturday and the followed by friday ,wednesday, thursday, tuesday and then mon and least sun.

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df' and the column with days of the week is 'Day of Week'
day_counts = df['Day of Week'].value_counts()

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.bar(day_counts.index, day_counts.values)
plt.xlabel("Day of the Week")
plt.ylabel("Number of Releases")
plt.title("Content Release Frequency by Day")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df1.index, df1.values, label='Shows')
plt.bar(df2.index, df2.values, label='Movies', bottom=df1.values) # Stacked bar for movies
plt.xlabel("Day of the Week")
plt.ylabel("Number of Releases")
plt.title("Content Release Frequency by Day (Shows and Movies)")
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-b6c7e174c08a> in <cell line: 2>()
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.bar(df1.index, df1.values, label='Shows')
#       3 plt.bar(df2.index, df2.values, label='Movies', bottom=df1.values) # Stacked bar for movies
#       4 plt.xlabel("Day of the Week")
#       5 plt.ylabel("Number of Releases")
#
# NameError: name 'df1' is not defined

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title='Netflix Report')
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-12-30 08:55:22.262020&quot;&gt;&lt;title&gt;Netflix Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
df['Release Date'].interpolate(method='linear')
# Out:
# 0       2023-03-23 00:00:00
# 1       2023-01-05 00:00:00
# 2       2022-12-30 00:00:00
# 3       2022-11-23 00:00:00
# 4       2023-05-04 00:00:00
#                 ...
# 24807   2019-01-11 12:00:00
# 24808   2019-07-30 00:00:00
# 24809   2022-07-26 00:00:00
# 24810   2020-09-28 00:00:00
# 24811   2020-09-28 00:00:00
# Name: Release Date, Length: 24812, dtype: datetime64[ns]

# %%
df['Release Date'] = pd.to_datetime(df['Release Date'])

# Extract year and month
df['year_added'] = df['Release Date'].dt.year
df['month_added'] = df['Release Date'].dt.month

# Display the updated DataFrame (optional)
print(df[['Release Date', 'year_added', 'month_added']].head())
df.head()
# Out:
#   Release Date  year_added  month_added
# 0   2023-03-23      2023.0          3.0
# 1   2023-01-05      2023.0          1.0
# 2   2022-12-30      2022.0         12.0
# 3   2022-11-23      2022.0         11.0
# 4   2023-05-04      2023.0          5.0
#                                  Title Available Globally? Release Date  \
# 0            The Night Agent: Season 1                 Yes   2023-03-23
# 1            Ginny & Georgia: Season 2                 Yes   2023-01-05
# 2   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes   2022-12-30
# 3                  Wednesday: Season 1                 Yes   2022-11-23
# 4  Queen Charlotte: A Bridgerton Story                 Yes   2023-05-04
#
#   Day of Week  Hours Viewed Language Indicator Content Type  year_added  \
# 0         Thu  81,21,00,000            English         Show      2023.0
# 1         Thu  66,51,00,000            English         Show      2023.0
# 2         Fri  62,28,00,000             Korean         Show      2022.0
# ...

# %%
df.isnull().sum()
# Out:
# Title                      0
# Available Globally?        0
# Release Date           16646
# Day of Week                0
# Hours Viewed               0
# Language Indicator         0
# Content Type               0
# year_added             16646
# month_added            16646
# dtype: int64
